# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset
data = pd.read_csv("../Dataset3.csv")

# %%
# Box Plot for all features
plt.figure(figsize=(20, 7))
data.boxplot(grid=False)
plt.title("Box Plot for Dataset Features")
plt.xticks(rotation=45)
plt.show()

# %%
# Histograms for all features
plt.figure(figsize=(16, 10))
data.hist(bins=20, figsize=(16, 10))
plt.suptitle("Histograms for Dataset Features", y=1.02)
plt.show()

# %%
# Scatter Matrix for a subset of features (adjust as needed)
from pandas.plotting import scatter_matrix
scatter_matrix(data[['url_length', 'valid_url', 'at_symbol','sensitive_words_count', 'isHttps', 'nb_dots','nb_hyphens', 'nb_and', 'nb_or','nb_www', 'nb_com', 'nb_underscore','target']], alpha=0.5, figsize=(10, 10), diagonal='hist')
plt.suptitle("Scatter Matrix for Selected Features", y=0.92)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# f:\Learning Data\10th semester (fall 23-24)\Machine Learning in Cyber Security\Group Activity\Dataset_Visulization\DipeshMain.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/f%3A/Learning%20Data/10th%20semester%20%28fall%2023-24%29/Machine%20Learning%20in%20Cyber%20Security/Group%20Activity/Dataset_Visulization/DipeshMain.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # Scatter Matrix for a subset of features (adjust as needed)
#       <a href='vscode-notebook-cell:/f%3A/Learning%20Data/10th%20semester%20%28fall%2023-24%29/Machine%20Learning%20in%20Cyber%20Security/Group%20Activity/Dataset_Visulization/DipeshMain.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> from pandas.plotting import scatter_matrix
# ----> <a href='vscode-notebook-cell:/f%3A/Learning%20Data/10th%20semester%20%28fall%2023-24%29/Machine%20Learning%20in%20Cyber%20Security/Group%20Activity/Dataset_Visulization/DipeshMain.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> scatter_matrix(data[['url_length', 'valid_url', 'at_symbol','sensitive_words_count', 'isHttps', 'nb_dots','nb_hyphens', 'nb_and', 'nb_or','nb_www', 'nb_com', 'nb_underscore','target']], alpha=0.5, figsize=(10, 10), diagonal='hist')
#       <a href='vscode-notebook-cell:/f%3A/Learning%20Data/10th%20semester%20%28fall%2023-24%29/Machine%20Learning%20in%20Cyber%20Security/Group%20Activity/Dataset_Visulization/DipeshMain.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> plt.suptitle("Scatter Matrix for Selected Features", y=0.92)
#       <a href='vscode-notebook-cell:/f%3A/Learning%20Data/10th%20semester%20%28fall%2023-24%29/Machine%20Learning%20in%20Cyber%20Security/Group%20Activity/Dataset_Visulization/DipeshMain.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> plt.show()
#
# File c:\Users\smart\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\smart\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File c:\Users\smart\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5936     if use_interval_msg:
#    5937         key = list(key)
# -> 5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['url_length', 'valid_url', 'at_symbol', 'sensitive_words_count',\n       'isHttps', 'nb_dots', 'nb_hyphens', 'nb_and', 'nb_or', 'nb_www',\n       'nb_com', 'nb_underscore', 'target'],\n      dtype='object')] are in the [columns]"
